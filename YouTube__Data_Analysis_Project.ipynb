# %% [markdown]
# # Data Cleaning and understanding

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/INvideos.csv')

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc      17.14.11
# 1  zUZ1z7FwLc8      17.14.11
# 2  10L1hZ9qa58      17.14.11
# 3  N1vE8iiEg64      17.14.11
# 4  kJzGH0PVQHQ      17.14.11
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           25  2017-11-13T05:43:56.000Z
# 2           24  2017-11-12T15:48:08.000Z
# 3           23  2017-11-12T07:08:48.000Z
# 4           24  2017-11-13T01:14:16.000Z
#
#                                                 tags    views  likes  \
# ...

# %% [markdown]
# First we will check whether the all columns in correct data types or not.

# %%
df.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id                int64
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object

# %% [markdown]
# # Data Cleaning

# %% [markdown]
#  **Problems**
#  1. trending_date column is in object.
#  2. publish_time column is also is in object.

# %% [markdown]
# to change this in pandas date time format using pd.to_datetime

# %%
pd.to_datetime(df['trending_date'], format = '%y.%d.%m')
# Out:
# 0       2017-11-14
# 1       2017-11-14
# 2       2017-11-14
# 3       2017-11-14
# 4       2017-11-14
#            ...
# 37347   2018-06-14
# 37348   2018-06-14
# 37349   2018-06-14
# 37350   2018-06-14
# 37351   2018-06-14
# Name: trending_date, Length: 37352, dtype: datetime64[ns]

# %%
df['trending_date'] = pd.to_datetime(df['trending_date'], format = '%y.%d.%m')

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  zUZ1z7FwLc8    2017-11-14
# 2  10L1hZ9qa58    2017-11-14
# 3  N1vE8iiEg64    2017-11-14
# 4  kJzGH0PVQHQ    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id              publish_time  \
# 0            1  2017-11-12T12:20:39.000Z
# 1           25  2017-11-13T05:43:56.000Z
# 2           24  2017-11-12T15:48:08.000Z
# 3           23  2017-11-12T07:08:48.000Z
# 4           24  2017-11-13T01:14:16.000Z
#
#                                                 tags    views  likes  \
# ...

# %%
df.dtypes
# Out:
# video_id                          object
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# category_id                        int64
# publish_time                      object
# tags                              object
# views                              int64
# likes                              int64
# dislikes                           int64
# comment_count                      int64
# thumbnail_link                    object
# comments_disabled                   bool
# ratings_disabled                    bool
# video_error_or_removed              bool
# description                       object
# dtype: object

# %%
pd.to_datetime(df['publish_time'])
# Out:
# 0       2017-11-12 12:20:39+00:00
# 1       2017-11-13 05:43:56+00:00
# 2       2017-11-12 15:48:08+00:00
# 3       2017-11-12 07:08:48+00:00
# 4       2017-11-13 01:14:16+00:00
#                    ...
# 37347   2018-06-13 08:01:11+00:00
# 37348   2018-06-13 11:30:04+00:00
# 37349   2018-06-13 05:00:02+00:00
# 37350   2018-06-13 15:07:49+00:00
# 37351   2018-06-10 04:29:54+00:00
# Name: publish_time, Length: 37352, dtype: datetime64[ns, UTC]

# %%
df['publish_time'] = pd.to_datetime(df['publish_time'])

# %%
df.dtypes
# Out:
# video_id                               object
# trending_date                  datetime64[ns]
# title                                  object
# channel_title                          object
# category_id                             int64
# publish_time              datetime64[ns, UTC]
# tags                                   object
# views                                   int64
# likes                                   int64
# dislikes                                int64
# comment_count                           int64
# thumbnail_link                         object
# comments_disabled                        bool
# ratings_disabled                         bool
# video_error_or_removed                   bool
# description                            object
# dtype: object

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  zUZ1z7FwLc8    2017-11-14
# 2  10L1hZ9qa58    2017-11-14
# 3  N1vE8iiEg64    2017-11-14
# 4  kJzGH0PVQHQ    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id              publish_time  \
# 0            1 2017-11-12 12:20:39+00:00
# 1           25 2017-11-13 05:43:56+00:00
# 2           24 2017-11-12 15:48:08+00:00
# 3           23 2017-11-12 07:08:48+00:00
# 4           24 2017-11-13 01:14:16+00:00
#
#                                                 tags    views  likes  \
# ...

# %%
df['publish_time'].dt.date
# Out:
# 0        2017-11-12
# 1        2017-11-13
# 2        2017-11-12
# 3        2017-11-12
# 4        2017-11-13
#             ...
# 37347    2018-06-13
# 37348    2018-06-13
# 37349    2018-06-13
# 37350    2018-06-13
# 37351    2018-06-10
# Name: publish_time, Length: 37352, dtype: object

# %%
df['publish_date'] = pd.to_datetime(df['publish_time'].dt.date)
df['publish_time'] = df['publish_time'].dt.time

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  zUZ1z7FwLc8    2017-11-14
# 2  10L1hZ9qa58    2017-11-14
# 3  N1vE8iiEg64    2017-11-14
# 4  kJzGH0PVQHQ    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id publish_time  \
# 0            1     12:20:39
# 1           25     05:43:56
# 2           24     15:48:08
# 3           23     07:08:48
# 4           24     01:14:16
#
#                                                 tags    views  likes  \
# 0  sharry mann|"sharry mann new song"|"sharry man...  1096327  33966
# ...

# %%
df.dtypes
# Out:
# video_id                          object
# trending_date             datetime64[ns]
# title                             object
# channel_title                     object
# category_id                        int64
# publish_time                      object
# tags                              object
# views                              int64
# likes                              int64
# dislikes                           int64
# comment_count                      int64
# thumbnail_link                    object
# comments_disabled                   bool
# ratings_disabled                    bool
# video_error_or_removed              bool
# description                       object
# publish_date              datetime64[ns]
# dtype: object

# %% [markdown]
# # Problem statement formulation & Hypothesis
# Problem Statement
# 1. Pattern behind those videos that were trending on the same of the upload.
# 2. T-series analyis

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  zUZ1z7FwLc8    2017-11-14
# 2  10L1hZ9qa58    2017-11-14
# 3  N1vE8iiEg64    2017-11-14
# 4  kJzGH0PVQHQ    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id publish_time  \
# 0            1     12:20:39
# 1           25     05:43:56
# 2           24     15:48:08
# 3           23     07:08:48
# 4           24     01:14:16
#
#                                                 tags    views  likes  \
# 0  sharry mann|"sharry mann new song"|"sharry man...  1096327  33966
# ...

# %%
df.sort_values(by = 'views', ascending = False)
# Out:
#           video_id trending_date  \
# 5408   FlsCjmMhFmw    2017-12-12
# 5119   FlsCjmMhFmw    2017-12-11
# 4936   FlsCjmMhFmw    2017-12-10
# 4477   6ZfuNTqbHE8    2017-12-07
# 4236   6ZfuNTqbHE8    2017-12-06
# ...            ...           ...
# 5290   p3Wn9FuI2zo    2017-12-11
# 18320       #NAME?    2018-02-22
# 20323  18OSLOq-bFA    2018-03-06
# 29317  iW5ZRboFCMU    2018-05-01
# 29316  wntggWeDxjI    2018-05-01
#
#                                                    title  \
# 5408   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 5119   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 4936   YouTube Rewind: The Shape of 2017 | #YouTubeRe...
# 4477   Marvel Studios' Avengers: Infinity War Officia...
# 4236   Marvel Studios' Avengers: Infinity War Officia...
# ...                                                  ...
# 5290   Dilip Ghosh and Firhad Hakim's political fight...
# 18320  Madhuban Murli LIVE - 22/2/2018 (Thursday 7.00...
# ...

# %%
df.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description', 'publish_date'],
#       dtype='object')

# %%
df[['video_id', 'trending_date', 'publish_date', 'title', 'views']]
# Out:
#           video_id trending_date publish_date  \
# 0      kzwfHumJyYc    2017-11-14   2017-11-12
# 1      zUZ1z7FwLc8    2017-11-14   2017-11-13
# 2      10L1hZ9qa58    2017-11-14   2017-11-12
# 3      N1vE8iiEg64    2017-11-14   2017-11-12
# 4      kJzGH0PVQHQ    2017-11-14   2017-11-13
# ...            ...           ...          ...
# 37347  iNHecA3PJCo    2018-06-14   2018-06-13
# 37348  dpPmPbhcslM    2018-06-14   2018-06-13
# 37349  mV6aztP58f8    2018-06-14   2018-06-13
# 37350  qxqDNP1bDEw    2018-06-14   2018-06-13
# 37351  wERgpPK44w0    2018-06-14   2018-06-10
#
#                                                    title    views
# 0      Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  1096327
# 1      पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...   590101
# 2      Stylish Star Allu Arjun @ ChaySam Wedding Rece...   473988
# 3                         Eruma Saani | Tamil vs English  1242680
# 4      why Samantha became EMOTIONAL @ Samantha naga ...   464015
# ...

# %%
df[df['video_id']== 'FlsCjmMhFmw'][['video_id', 'trending_date', 'publish_date', 'title', 'views']]
# Out:
#          video_id trending_date publish_date  \
# 4459  FlsCjmMhFmw    2017-12-07   2017-12-06
# 4568  FlsCjmMhFmw    2017-12-08   2017-12-06
# 4743  FlsCjmMhFmw    2017-12-09   2017-12-06
# 4936  FlsCjmMhFmw    2017-12-10   2017-12-06
# 5119  FlsCjmMhFmw    2017-12-11   2017-12-06
# 5408  FlsCjmMhFmw    2017-12-12   2017-12-06
#
#                                                   title      views
# 4459  YouTube Rewind: The Shape of 2017 | #YouTubeRe...   24784863
# 4568  YouTube Rewind: The Shape of 2017 | #YouTubeRe...   52611730
# 4743  YouTube Rewind: The Shape of 2017 | #YouTubeRe...   75969469
# 4936  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  100911567
# 5119  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  113876217
# 5408  YouTube Rewind: The Shape of 2017 | #YouTubeRe...  125432237
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ...

# %% [markdown]
# There are two things that we can understand from this data the way that the data has been presented to us.
# 1. The number of times we have the video_id in the data, it represents the number of days the video was on the trending list.
# 2. The final row for each video_id is the row with the final number of views, likes, counts and all other parameters.

# %%
# create a new column with each video_id and the number of days it was trending

df['video_id'].value_counts()
# Out:
# video_id
# #NAME?         511
# rRr1qiJRsXk     16
# l7E0kTvARsA     14
# 1J76wN0TPI4     14
# WDiK14qI3pQ     13
#               ...
# hOh8ck_ipHk      1
# NHPPVfr24-Q      1
# FeFEtBL4dcs      1
# zvjNaSmQFLQ      1
# 3MTCSll3KGU      1
# Name: count, Length: 16307, dtype: int64

# %%
# ignore the first row

df['video_id'].value_counts()[1:]
# Out:
# video_id
# rRr1qiJRsXk    16
# l7E0kTvARsA    14
# 1J76wN0TPI4    14
# WDiK14qI3pQ    13
# bYSRPuDEnTg    13
#                ..
# hOh8ck_ipHk     1
# NHPPVfr24-Q     1
# FeFEtBL4dcs     1
# zvjNaSmQFLQ     1
# 3MTCSll3KGU     1
# Name: count, Length: 16306, dtype: int64

# %%
# convert this into data frame

df['video_id'].value_counts()[1:].reset_index()
# Out:
#           video_id  count
# 0      rRr1qiJRsXk     16
# 1      l7E0kTvARsA     14
# 2      1J76wN0TPI4     14
# 3      WDiK14qI3pQ     13
# 4      bYSRPuDEnTg     13
# ...            ...    ...
# 16301  hOh8ck_ipHk      1
# 16302  NHPPVfr24-Q      1
# 16303  FeFEtBL4dcs      1
# 16304  zvjNaSmQFLQ      1
# 16305  3MTCSll3KGU      1
#
# [16306 rows x 2 columns]

# %%
# preserve the last row for each video_id that has been duplicated.

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 37347     True
# 37348     True
# 37349     True
# 37350     True
# 37351     True
# Length: 37352, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 4263

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# df.drop_duplicates(subset = 'video_id', keep = 'last', inplace = True)

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  kzwfHumJyYc    2017-11-14
# 1  zUZ1z7FwLc8    2017-11-14
# 2  10L1hZ9qa58    2017-11-14
# 3  N1vE8iiEg64    2017-11-14
# 4  kJzGH0PVQHQ    2017-11-14
#
#                                                title    channel_title  \
# 0  Sharry Mann: Cute Munda ( Song Teaser) | Parmi...  Lokdhun Punjabi
# 1  पीरियड्स के समय, पेट पर पति करता ऐसा, देखकर दं...          HJ NEWS
# 2  Stylish Star Allu Arjun @ ChaySam Wedding Rece...             TFPC
# 3                     Eruma Saani | Tamil vs English      Eruma Saani
# 4  why Samantha became EMOTIONAL @ Samantha naga ...       Filmylooks
#
#    category_id publish_time  \
# 0            1     12:20:39
# 1           25     05:43:56
# 2           24     15:48:08
# 3           23     07:08:48
# 4           24     01:14:16
#
#                                                 tags    views  likes  \
# 0  sharry mann|"sharry mann new song"|"sharry man...  1096327  33966
# ...

# %%
# df[df['video_id']== 'FlsCjmMhFmw'][['video_id', 'trending_date', 'publish_date', 'title', 'views']]

# %% [markdown]
# Now We will start the Analysis.
# 1. Trending on the same day as they were published?

# %%
df[df['publish_date'] == df['trending_date']]
# Out:
#           video_id trending_date  \
# 431    bvmlbu5Vipg    2017-11-16
# 2373   _r0mH98oPlg    2017-11-26
# 2903   j_Vlg4K05s8    2017-11-29
# 3681   Khg8JCK6PMI    2017-12-03
# 5333   wS7okEDsAWI    2017-12-12
# ...            ...           ...
# 36598  pq-eP_RCclI    2018-06-10
# 36716  fUoc7FMuwdY    2018-06-11
# 36723  8_ei7sQJ4FY    2018-06-11
# 36773  z7ddTuNukvQ    2018-06-11
# 36874  v9a6l_s2PKM    2018-06-12
#
#                                                    title  \
# 431    गुरुवार स्पेशल भजन : साईं बाबा रहमत की नज़र कर ...
# 2373   RAMAYANAM PART- 7 | Bahubali Ramayanam | Unkno...
# 2903   Dil De Kareeb | Garry Sandhu ( Full Video ) | ...
# 3681   RAMAYANAM PART - 10 | CLIMAX | Unknown Facts A...
# 5333   हनुमान चालीसा, Hanuman Chalisa Hari Om Sharan ...
# ...                                                  ...
# 36598             ఏసీల్లో కూర్చొని ఎవరైనా మాట్లాడుతారు..
# 36716  CET Common Eligibility test & Its Effect on st...
# ...

# %%
same_day = df[df['publish_date'] == df['trending_date']]

# %%
same_day.head()
# Out:
#          video_id trending_date  \
# 431   bvmlbu5Vipg    2017-11-16
# 2373  _r0mH98oPlg    2017-11-26
# 2903  j_Vlg4K05s8    2017-11-29
# 3681  Khg8JCK6PMI    2017-12-03
# 5333  wS7okEDsAWI    2017-12-12
#
#                                                   title  \
# 431   गुरुवार स्पेशल भजन : साईं बाबा रहमत की नज़र कर ...
# 2373  RAMAYANAM PART- 7 | Bahubali Ramayanam | Unkno...
# 2903  Dil De Kareeb | Garry Sandhu ( Full Video ) | ...
# 3681  RAMAYANAM PART - 10 | CLIMAX | Unknown Facts A...
# 5333  हनुमान चालीसा, Hanuman Chalisa Hari Om Sharan ...
#
#               channel_title  category_id publish_time  \
# 431          Sonotek Bhakti           10     00:00:02
# 2373          Vikram Aditya           24     03:04:54
# 2903    Fresh Media Records           10     02:36:54
# 3681          Vikram Aditya           24     03:00:52
# 5333  T-Series Bhakti Sagar           10     01:30:01
#
#                                                    tags   views  likes  \
# ...

# %%
same_day['channel_title'].value_counts()[:20]
# Out:
# channel_title
# Adda247 :Official Channel of BankersAdda & SSCAdda    48
# WiFiStudy                                             28
# Mahendra Guru : Online Videos For Govt. Exams         16
# Study IQ education                                    12
# T-Series Bhakti Sagar                                 11
# Vikram Aditya                                         10
# Kori Pati Productions                                  8
# Studio Saraswati Official                              8
# Wrestling Time                                         6
# WWE                                                    6
# Zee Tamil                                              6
# Zee Yuva                                               5
# Speed Records                                          4
# Mazhavil Manorama                                      4
# Pagal Gujju                                            4
# Asianet                                                4
# ...

# %% [markdown]
# # T-series

# %%
df.drop_duplicates(subset = 'video_id', keep = 'last', inplace = True)

# %%
tseries = df[df['channel_title']=='T-Series']

# %%
tseries.shape
# Out:
# (62, 17)

# %%
tseries.head()
# Out:
#          video_id trending_date  \
# 731   c64I9HNpiOY    2017-11-17
# 1296  VXOJPfk5k9o    2017-11-20
# 2006  gu_cSXf1zGo    2017-11-24
# 2266  rewrhR1sKx8    2017-11-25
# 3382  Lx4ESwFT9mk    2017-12-01
#
#                                                   title channel_title  \
# 731   Padmavati : Ek Dil Ek Jaan Video Song | Deepik...      T-Series
# 1296  Official Trailer: Bulbul | Divya Khosla Kumar ...      T-Series
# 2006  Official Trailer: Sallu Ki Shaadi | Movie Rele...      T-Series
# 2266  Song Teaser: Ik Kahani | Gajendra Verma | Vikr...      T-Series
# 3382  Ban Ja Rani Full Song (Video) | Tumhari Sulu |...      T-Series
#
#       category_id publish_time  \
# 731            10     06:14:19
# 1296           10     06:30:01
# 2006           10     12:36:01
# 2266           10     09:39:08
# 3382           10     11:55:46
#
#                                                    tags     views   likes  \
# ...

# %%
tseries['month'] = tseries['publish_date'].dt.month
# Out:
# <ipython-input-42-e55caffbdd82>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tseries['month'] = tseries['publish_date'].dt.month

# %%
tseries['month'].value_counts()
# Out:
# month
# 2     11
# 3     10
# 12     9
# 1      9
# 5      8
# 4      6
# 11     5
# 6      4
# Name: count, dtype: int64

# %%
tseries[tseries['month']== 2]
# Out:
#           video_id trending_date  \
# 15369  9aoUpCXY7uk    2018-02-06
# 15891  3h4thS-Hcrk    2018-02-09
# 16443  yIIGQB6EMAM    2018-02-12
# 16762  h8bvxiE3KCo    2018-02-13
# 16999  13z2kF6TiCc    2018-02-15
# 17717  XXfTL-umTnE    2018-02-19
# 17919  5sVGug6dxt4    2018-02-20
# 18036  WZ00WbDS2Gc    2018-02-21
# 18173  UCoogBnurWk    2018-02-22
# 18336  TDF1qdUtbzw    2018-02-23
# 19107  w5YunG1wilA    2018-02-27
#
#                                                    title channel_title  \
# 15369  Padmaavat: Binte Dil Video Song | Arijit Singh...      T-Series
# 15891  Raid | Official Trailer | Ajay Devgn | Ileana ...      T-Series
# 16443  Bom Diggy Diggy (Video) | Zack Knight | Jasmin...      T-Series
# 16762  Boond Boond | Hate Story IV | Urvashi Rautela ...      T-Series
# 16999  Sanu Ek Pal Chain Video | Raid | Ajay Devgn | ...      T-Series
# 17717  Hatt Ja Tau Video | Veerey Ki Wedding | Sunidh...      T-Series
# ...

# %%
tseries[tseries['month']== 12]
# Out:
#          video_id trending_date  \
# 3985  nxjeWmQeOgU    2017-12-04
# 4834  vIA73i3Juwk    2017-12-09
# 5056  7dgjSAaLC3U    2017-12-10
# 5617  yvDUw2rdaeg    2017-12-13
# 5753  9vnhToVxgUU    2017-12-14
# 6912  dZ0fwJojhrs    2017-12-20
# 7653  M2q64UowX9g    2017-12-24
# 7998  P8ZWk3S14ec    2017-12-26
# 9380  xWi8nDUjHGA    2018-01-02
#
#                                                   title channel_title  \
# 3985    Official  Song Teaser: Kisko Pata | Yash Wadali      T-Series
# 4834  Bulbul: Short Film | Divya Khosla Kumar | Shiv...      T-Series
# 5056  T-Series Mixtape Punjabi: 3 Peg/Label Black So...      T-Series
# 5617  T-Series Mixtape Punjabi: 3 Peg/Label Black So...      T-Series
# 5753  Song Teaser: SunDowner | AVI J | Releasing On ...      T-Series
# 6912  Guru Randhawa: Lahore (Official Video) Bhushan...      T-Series
# 7653  Official Trailer: Sonu Ke Titu Ki Sweety | Luv...      T-Series
# 7998  Yo Yo Honey Singh: Dil Chori (Song Teaser) | S...      T-Series
# ...

# %%
100*tseries['month'].value_counts(normalize = True)
# Out:
# month
# 2     17.741935
# 3     16.129032
# 12    14.516129
# 1     14.516129
# 5     12.903226
# 4      9.677419
# 11     8.064516
# 6      6.451613
# Name: proportion, dtype: float64

# %%
17.74+16.12+14.5+14.5
# Out:
# 62.86
